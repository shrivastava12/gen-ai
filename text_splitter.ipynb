# %%
# Reading a pdf file
from langchain_community.document_loaders import PyPDFLoader
loader = PyPDFLoader('sample.pdf')
docs = loader.load()
docs
# Out:
# /Users/pankaj/project/python/langchain/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# [Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Untitled document', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='Pankaj  Kishor  Senior  Consultant  |  Full  Stack  Developer  (Web,  Mobile,  Cloud)   Email:  pankaj.kishor@email.com  LinkedIn:  https://www.linkedin.com/in/pankaj-kishor-1614b818b/  Location:  India   --------------------------------------------   PROFESSIONAL  SUMMARY   Full  Stack  Developer  with  4+  years  of  experience  in  designing,  developing,  and  deploying  scalable  web  and  mobile  applications.  Strong  expertise  in  ReactJS,  Node.js,  REST  APIs,  GraphQL,  and  cloud-based  architectures.  Experienced  in  working  in  agile  environments  and  delivering  enterprise-grade  solutions.   --------------------------------------------   WORK  EXPERIENCE   Senior  Consultant  Ernst  &  Young  (EY)  July  2022  –  Present   -  Working  as  a  Full  Stack  Developer  on  large-scale  enterprise  applications  -  Designing  and  developing  reusable  UI  components  using  ReactJS  and  Material  UI  -  Building  backend  services  using  Node.js  and  GraphQL  -  Integrating  Kafka-based  data  pipelines  for  real-time  processing  -  Collaborating  with  product  managers  and  stakeholders  to  define  requirements  -  Mentoring  junior  developers  and  conducting  code  reviews   Software  Engineer  Previous  Organization  June  2020  –  June  2022   -  Developed  and  maintained  web  applications  using  ReactJS  and  JavaScript  -  Implemented  REST  APIs  using  Node.js  and  Express  -  Worked  with  MySQL  and  PostgreSQL  databases  -  Improved  application  performance  and  reduced  load  times  -  Participated  in  sprint  planning  and  agile  ceremonies   --------------------------------------------'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Untitled document', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='TECHNICAL  SKILLS   Frontend:  -  ReactJS  -  JavaScript  (ES6+)  -  HTML5,  CSS3  -  Material  UI   Backend:  -  Node.js  -  Express.js  -  GraphQL  -  REST  APIs   Databases:  -  MySQL  -  PostgreSQL  -  ClickHouse   DevOps  &  Cloud:  -  Docker  -  Kubernetes  -  AWS  -  Azure   Messaging  &  Streaming:  -  Kafka   Tools:  -  Git  -  Jira  -  Postman   --------------------------------------------   EDUCATION   Master  of  Computer  Applications  (MCA)  Indira  Gandhi  National  Open  University  (IGNOU)  2023  –  Present   Bachelor  of  Computer  Applications  (BCA)  University  Name  2017  –  2020'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Untitled document', 'source': 'sample.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='--------------------------------------------   PROJECTS   Fleet  Management  System  -  Built  a  real-time  vehicle  tracking  system  -  Implemented  live  data  ingestion  using  Kafka  -  Developed  dashboards  using  ReactJS  and  GraphQL   --------------------------------------------   CERTIFICATIONS   -  AWS  Certified  Cloud  Practitioner  -  ReactJS  Advanced  Certification   --------------------------------------------   ADDITIONAL  INFORMATION   -  Strong  problem-solving  skills  -  Excellent  communication  and  teamwork  -  Experience  mentoring  interns')]

# %%
type(docs[0])
# Out:
# langchain_core.documents.base.Document

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size=500,chunk_overlap=50)
final_documents = text_splitter.split_documents(docs)
final_documents
# Out:
# [Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Untitled document', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='Pankaj  Kishor  Senior  Consultant  |  Full  Stack  Developer  (Web,  Mobile,  Cloud)   Email:  pankaj.kishor@email.com  LinkedIn:  https://www.linkedin.com/in/pankaj-kishor-1614b818b/  Location:  India   --------------------------------------------   PROFESSIONAL  SUMMARY   Full  Stack  Developer  with  4+  years  of  experience  in  designing,  developing,  and  deploying  scalable  web  and  mobile  applications.  Strong  expertise  in  ReactJS,  Node.js,  REST  APIs,  GraphQL,  and'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Untitled document', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='ReactJS,  Node.js,  REST  APIs,  GraphQL,  and  cloud-based  architectures.  Experienced  in  working  in  agile  environments  and  delivering  enterprise-grade  solutions.   --------------------------------------------   WORK  EXPERIENCE   Senior  Consultant  Ernst  &  Young  (EY)  July  2022  –  Present   -  Working  as  a  Full  Stack  Developer  on  large-scale  enterprise  applications  -  Designing  and  developing  reusable  UI  components  using  ReactJS  and  Material  UI  -'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Untitled document', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='components  using  ReactJS  and  Material  UI  -  Building  backend  services  using  Node.js  and  GraphQL  -  Integrating  Kafka-based  data  pipelines  for  real-time  processing  -  Collaborating  with  product  managers  and  stakeholders  to  define  requirements  -  Mentoring  junior  developers  and  conducting  code  reviews   Software  Engineer  Previous  Organization  June  2020  –  June  2022   -  Developed  and  maintained  web  applications  using  ReactJS  and  JavaScript  -'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Untitled document', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='applications  using  ReactJS  and  JavaScript  -  Implemented  REST  APIs  using  Node.js  and  Express  -  Worked  with  MySQL  and  PostgreSQL  databases  -  Improved  application  performance  and  reduced  load  times  -  Participated  in  sprint  planning  and  agile  ceremonies   --------------------------------------------'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Untitled document', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='TECHNICAL  SKILLS   Frontend:  -  ReactJS  -  JavaScript  (ES6+)  -  HTML5,  CSS3  -  Material  UI   Backend:  -  Node.js  -  Express.js  -  GraphQL  -  REST  APIs   Databases:  -  MySQL  -  PostgreSQL  -  ClickHouse   DevOps  &  Cloud:  -  Docker  -  Kubernetes  -  AWS  -  Azure   Messaging  &  Streaming:  -  Kafka   Tools:  -  Git  -  Jira  -  Postman   --------------------------------------------   EDUCATION   Master  of  Computer  Applications  (MCA)  Indira  Gandhi  National  Open'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Untitled document', 'source': 'sample.pdf', 'total_pages': 3, 'page': 1, 'page_label': '2'}, page_content='(MCA)  Indira  Gandhi  National  Open  University  (IGNOU)  2023  –  Present   Bachelor  of  Computer  Applications  (BCA)  University  Name  2017  –  2020'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Untitled document', 'source': 'sample.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='--------------------------------------------   PROJECTS   Fleet  Management  System  -  Built  a  real-time  vehicle  tracking  system  -  Implemented  live  data  ingestion  using  Kafka  -  Developed  dashboards  using  ReactJS  and  GraphQL   --------------------------------------------   CERTIFICATIONS   -  AWS  Certified  Cloud  Practitioner  -  ReactJS  Advanced  Certification   --------------------------------------------   ADDITIONAL  INFORMATION   -  Strong  problem-solving  skills  -'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Untitled document', 'source': 'sample.pdf', 'total_pages': 3, 'page': 2, 'page_label': '3'}, page_content='-  Strong  problem-solving  skills  -  Excellent  communication  and  teamwork  -  Experience  mentoring  interns')]

# %%
print(final_documents[0])
print(final_documents[1])
# Out:
# page_content='Pankaj  Kishor  Senior  Consultant  |  Full  Stack  Developer  (Web,  Mobile,  Cloud)   Email:  pankaj.kishor@email.com  LinkedIn:  https://www.linkedin.com/in/pankaj-kishor-1614b818b/  Location:  India   --------------------------------------------   PROFESSIONAL  SUMMARY   Full  Stack  Developer  with  4+  years  of  experience  in  designing,  developing,  and  deploying  scalable  web  and  mobile  applications.  Strong  expertise  in  ReactJS,  Node.js,  REST  APIs,  GraphQL,  and' metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Untitled document', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}
# page_content='ReactJS,  Node.js,  REST  APIs,  GraphQL,  and  cloud-based  architectures.  Experienced  in  working  in  agile  environments  and  delivering  enterprise-grade  solutions.   --------------------------------------------   WORK  EXPERIENCE   Senior  Consultant  Ernst  &  Young  (EY)  July  2022  –  Present   -  Working  as  a  Full  Stack  Developer  on  large-scale  enterprise  applications  -  Designing  and  developing  reusable  UI  components  using  ReactJS  and  Material  UI  -' metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Untitled document', 'source': 'sample.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}

# %%
# Text loader

from langchain_community.document_loaders import TextLoader

loader = TextLoader('speech.txt')
docs = loader.load()
docs
# Out:
# [Document(metadata={'source': 'speech.txt'}, page_content='Senior Consultant @ EY | Web | Mobile | Cloud · Full-stack developer with 4+ years of experience building scalable web and mobile applications using ReactJS, ...\n``` :contentReference[oaicite:4]{index=4}\n\n*(This headline is taken from search previews of your LinkedIn profile.)*\n\n---\n\n## **🧠 Experience & Skills (Inferred / Typical for Role)**\n\nBased on your public headline, your professional domain likely includes:\n\n### **Core Technical Skills**\n- **Frontend:** ReactJS / JavaScript / HTML / CSS :contentReference[oaicite:5]{index=5}  \n- **Backend:** Node.js / REST APIs / Cloud-based architectures :contentReference[oaicite:6]{index=6}  \n- **Mobile:** Web & mobile application experience :contentReference[oaicite:7]{index=7}  \n- **Cloud Technologies:** Cloud solutions and deployment platforms :contentReference[oaicite:8]{index=8}  \n- **Full-Stack Development:** End-to-end application building :contentReference[oaicite:9]{index=9}\n\n### **Professional Experience**\n- **Senior Consultant at EY**  \n  Likely working in technology consulting, overseeing web & mobile projects and delivering scalable solutions. :contentReference[oaicite:10]{index=10}\n\n*(Exact role descriptions, dates, companies, and accomplishments from your profile weren’t accessible publicly. If you want a full detailed extraction, paste the **exported LinkedIn profile PDF** or send a **screenshot** of sections like Experience, Education, Skills, and About.)*\n\n---\n\n## **✅ What’s Missing (To Complete Profile Text)**\nTo produce a **full text dump from your actual LinkedIn page**, I need one of the following:\n1. **LinkedIn export** file (.pdf/.docx) of your profile  \n2. **Screenshots** of your profile sections (About, Experience, Education, Skills, Projects)  \n3. **Plain text copy-paste** of your summary & work experience\n\nJust send any of the above and I’ll compile it into a **clean polished resume-style format** for you.\n\n---\n\nIf you want, I can also help you **rewrite your LinkedIn profile text** (About section, experience descriptions, skills list) to make it stand out — just ask!\n::contentReference[oaicite:11]{index=11}\n')]

# %%
speech=""
with open("speech.txt") as f:
    speech = f.read()

speech

text_splitter = RecursiveCharacterTextSplitter(chunk_size=100,chunk_overlap=20)
text = text_splitter.create_documents([speech])
text
# Out:
# [Document(metadata={}, page_content='Senior Consultant @ EY | Web | Mobile | Cloud · Full-stack developer with 4+ years of experience'),
#  Document(metadata={}, page_content='years of experience building scalable web and mobile applications using ReactJS, ...'),
#  Document(metadata={}, page_content='``` :contentReference[oaicite:4]{index=4}'),
#  Document(metadata={}, page_content='*(This headline is taken from search previews of your LinkedIn profile.)*\n\n---'),
#  Document(metadata={}, page_content='---\n\n## **🧠 Experience & Skills (Inferred / Typical for Role)**'),
#  Document(metadata={}, page_content='Based on your public headline, your professional domain likely includes:'),
#  Document(metadata={}, page_content='### **Core Technical Skills**'),
#  Document(metadata={}, page_content='- **Frontend:** ReactJS / JavaScript / HTML / CSS :contentReference[oaicite:5]{index=5}'),
#  Document(metadata={}, page_content='- **Backend:** Node.js / REST APIs / Cloud-based architectures'),
#  Document(metadata={}, page_content='architectures :contentReference[oaicite:6]{index=6}'),
#  Document(metadata={}, page_content='- **Mobile:** Web & mobile application experience :contentReference[oaicite:7]{index=7}'),
#  Document(metadata={}, page_content='- **Cloud Technologies:** Cloud solutions and deployment platforms'),
#  Document(metadata={}, page_content='platforms :contentReference[oaicite:8]{index=8}'),
#  Document(metadata={}, page_content='- **Full-Stack Development:** End-to-end application building :contentReference[oaicite:9]{index=9}'),
#  Document(metadata={}, page_content='### **Professional Experience**\n- **Senior Consultant at EY**'),
#  Document(metadata={}, page_content='Likely working in technology consulting, overseeing web & mobile projects and delivering scalable'),
#  Document(metadata={}, page_content='delivering scalable solutions. :contentReference[oaicite:10]{index=10}'),
#  Document(metadata={}, page_content='*(Exact role descriptions, dates, companies, and accomplishments from your profile weren’t'),
#  Document(metadata={}, page_content='profile weren’t accessible publicly. If you want a full detailed extraction, paste the **exported'),
#  Document(metadata={}, page_content='the **exported LinkedIn profile PDF** or send a **screenshot** of sections like Experience,'),
#  Document(metadata={}, page_content='like Experience, Education, Skills, and About.)*'),
#  Document(metadata={}, page_content='---'),
#  Document(metadata={}, page_content='## **✅ What’s Missing (To Complete Profile Text)**'),
#  Document(metadata={}, page_content='To produce a **full text dump from your actual LinkedIn page**, I need one of the following:'),
#  Document(metadata={}, page_content='1. **LinkedIn export** file (.pdf/.docx) of your profile'),
#  Document(metadata={}, page_content='2. **Screenshots** of your profile sections (About, Experience, Education, Skills, Projects)'),
#  Document(metadata={}, page_content='3. **Plain text copy-paste** of your summary & work experience'),
#  Document(metadata={}, page_content='Just send any of the above and I’ll compile it into a **clean polished resume-style format** for'),
#  Document(metadata={}, page_content='format** for you.'),
#  Document(metadata={}, page_content='---'),
#  Document(metadata={}, page_content='If you want, I can also help you **rewrite your LinkedIn profile text** (About section, experience'),
#  Document(metadata={}, page_content='section, experience descriptions, skills list) to make it stand out — just ask!'),
#  Document(metadata={}, page_content='::contentReference[oaicite:11]{index=11}')]
