# %%
import os 
from dotenv import load_dotenv
load_dotenv()

os.environ['OPENAI_API_KEY'] = os.getenv('OPENAI_API_KEY')
os.environ['LANGCHAIN_API_KEY'] = os.getenv('LANGCHAIN_API_KEY')
os.environ['LANGCHAIN_TRACING_V2'] = 'true'
os.environ['LANGCHAIN_TRACING_PROJECT_NAME'] = 'my_project'

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4o", temperature=0)
print(llm)
# Out:
# client=<openai.resources.chat.completions.completions.Completions object at 0x113eabbb0> async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x113f808e0> root_client=<openai.OpenAI object at 0x113eabb80> root_async_client=<openai.AsyncOpenAI object at 0x113f80f40> model_name='gpt-4o' temperature=0.0 model_kwargs={} openai_api_key=SecretStr('**********') stream_usage=True
# ...

# %%
#Input and get response from llm
response = llm.invoke("What is LangChain?")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 #Input and get response from llm
#       2 response = llm.invoke("What is LangChain?")
# ----> 3 print(response['content'])
#
# TypeError: 'AIMessage' object is not subscriptable

# %%
# Chatprompt Template
from langchain.prompts import ChatPromptTemplate
prompt = ChatPromptTemplate.from_messages([ 
    ("system", "You are an expert ai engineer. Provide me answer in brief."),
    ("user", "{text}"),
])

# %%
chain = prompt | llm
response = chain.invoke({"text": "Explain LangChain in brief."})
print(response)
# Out:
# content='LangChain is a framework designed to facilitate the development of applications powered by large language models (LLMs). It provides tools and abstractions to streamline the integration of LLMs into applications, enabling functionalities such as natural language understanding, generation, and interaction. LangChain supports various use cases, including chatbots, virtual assistants, and other AI-driven applications, by offering components for prompt management, memory handling, and interaction with external data sources.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 88, 'prompt_tokens': 30, 'total_tokens': 118, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_deacdd5f6f', 'id': 'chatcmpl-CwAepunPqt6t2vvJijcTKh0OethW
# ...

# %%
# output parser
from langchain_core.output_parsers import StrOutputParser
output_parser = StrOutputParser()
chain = prompt | llm | output_parser
response = chain.invoke({"text": "Explain LangChain in brief."})
print(response)
# Out:
# LangChain is a framework designed to facilitate the development of applications powered by large language models (LLMs). It provides tools and abstractions to streamline the integration of LLMs into applications, enabling developers to build complex workflows, manage interactions, and handle data processing efficiently. LangChain supports various use cases, including chatbots, data analysis, and content generation, by offering components for prompt management, memory handling, and API integration, among others.
